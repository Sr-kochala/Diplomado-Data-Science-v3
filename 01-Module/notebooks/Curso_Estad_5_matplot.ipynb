# %% [markdown]
# ## Visualizacion de datos

# %%
#Manejadores de Datos
import numpy as np
import pandas as pd

# %%
#Librerías de gráficos
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.style.use('ggplot')

# %%
print(plt.style.available) #Son los estilos disponibles
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# El set de datos a utilizar se encuentra en:\
# ('https://archive-beta.ics.uci.edu/ml/datasets/absenteeism+at+work')
# también se encuentra en los archivos del curso

# %%
base = pd.read_csv('Absenteeism_at_work.csv', delimiter=';')

# %%
base.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
base.shape
# Out:
# (740, 21)

# %%
base.dtypes
# Out:
# ID                                   int64
# Reason for absence                   int64
# Month of absence                     int64
# Day of the week                      int64
# Seasons                              int64
# Transportation expense               int64
# Distance from Residence to Work      int64
# Service time                         int64
# Age                                  int64
# Work load Average/day              float64
# Hit target                           int64
# Disciplinary failure                 int64
# Education                            int64
# Son                                  int64
# Social drinker                       int64
# Social smoker                        int64
# Pet                                  int64
# Weight                               int64
# Height                               int64
# Body mass index                      int64
# Absenteeism time in hours            int64
# dtype: object

# %%
base.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
base['Month of absence'].value_counts()
# Out:
# Month of absence
# 3     87
# 2     72
# 10    71
# 7     67
# 5     64
# 11    63
# 8     54
# 6     54
# 9     53
# 4     53
# 1     50
# 12    49
# 0      3
# Name: count, dtype: int64

# %%
base = base[base['Month of absence'] > 0]  # limpiando el cero

# %%
base.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  737.000000          737.000000        737.000000       737.000000
# mean    18.027137           19.294437          6.350068         3.913161
# std     11.007622            8.360679          3.419430         1.422090
# min      1.000000            0.000000          1.000000         2.000000
# 25%     10.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  737.000000              737.000000                       737.000000
# mean     2.546811              221.514247                        29.624152
# std      1.112329               66.960952                        14.843701
# ...

# %%
print ('Matplotlib version: ', mpl.__version__)
# Out:
# Matplotlib version:  3.8.0

# %% [markdown]
# ### Líneas

# %%
base_mes = base[['Month of absence', 'Absenteeism time in hours']]
base_mes = base_mes.groupby(['Month of absence']).sum()

# %%
base_mes.head()
# Out:
#                   Absenteeism time in hours
# Month of absence
# 1                                       222
# 2                                       294
# 3                                       765
# 4                                       482
# 5                                       400

# %%
base_mes.plot()
# Out:
# <Axes: xlabel='Month of absence'>

# %% [markdown]
# Pandas llena de forma automática la leyenda y el título para X, ahora reemplazemos por nuevos indices:

# %%
base_mes.rename(index={1:'ene', 2:'feb', 3:'mar', 4:'abr', 5:'may', 6:'jun', 7:'jul', 8:'ago', 9:'sep', 10:'oct', 11:'nov', 12:'dic'}, inplace=True)

# %%
base_mes.plot()
# Out:
# <Axes: xlabel='Month of absence'>

# %% [markdown]
# Agregando títulos:

# %%
base_mes.plot(kind='line')

plt.title('Ausentismo en Horas (suma total)')
plt.ylabel('Horas Totales')
plt.xlabel('Mes')

plt.show()

# %%
base_mes.plot(kind='line')

plt.title('Ausentismo en Horas (suma total)')
plt.ylabel('Horas Promedio')
plt.xlabel('Mes')

#ingresar una anotación
plt.text(6, 700, 'Verano en el Norte')
plt.text(2, 750, 'Vacaciones en colegios')

plt.show()

# %% [markdown]
# Ahora podemos comparar que grado de instrucción tienen más Ausentismo/hrs en todo el año\
# Según la documentación: Education (high school (1), graduate (2), postgraduate (3), master and doctor (4))

# %%
base['Education'].value_counts()
# Out:
# Education
# 1    608
# 3     79
# 2     46
# 4      4
# Name: count, dtype: int64

# %%
base['Education'].replace({1:'high school', 2:'graduate', 3:'postgraduate', 4:'master and doctor'}, inplace=True)

# %%
base_mes_edu = pd.pivot_table(base, index=['Month of absence'] , values=['Absenteeism time in hours'] , columns=['Education'], aggfunc=[np.mean])
#base_mes_edu = base_mes_edu.replace(np.nan, 0)
base_mes_edu.columns = base_mes_edu.columns.droplevel([0,1])
base_mes_edu.rename(index={1:'ene', 2:'feb', 3:'mar', 4:'abr', 5:'may', 6:'jun', 7:'jul', 8:'ago', 9:'sep', 10:'oct', 11:'nov', 12:'dic'}, inplace=True)
base_mes_edu
# Out:
# C:\Users\rclaure\AppData\Local\Temp\ipykernel_53856\3949699691.py:1: FutureWarning: The provided callable <function mean at 0x0000017DA99454E0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   base_mes_edu = pd.pivot_table(base, index=['Month of absence'] , values=['Absenteeism time in hours'] , columns=['Education'], aggfunc=[np.mean])
# Education          graduate  high school  master and doctor  postgraduate
# Month of absence
# ene                2.250000     4.025641                NaN      8.000000
# feb                3.200000     4.400000           2.000000      2.000000
# mar               16.000000     9.095890                NaN      3.700000
# abr                4.666667    10.372093                NaN      3.142857
# may                4.750000     7.317073           6.333333      3.583333
# ...

# %%
base_mes_edu.plot(kind='line')
plt.title('Horas de ausentismo por mes y educacion ')
plt.xlabel('Meses')
plt.ylabel('Horas')
# Out:
# Text(0, 0.5, 'Horas')

# %%
plt.style.use('dark_background')

# %%
base_mes_edu.plot(kind='line')
plt.title('Horas de ausentismo por mes y educacion ')
plt.xlabel('Meses')
plt.ylabel('Horas')
# Out:
# Text(0, 0.5, 'Horas')

# %%
plt.style.use('ggplot')

# %% [markdown]
# ### Configuraciones del Axes

# %%
fig = plt.figure()
ax = plt.axes()

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %%
#Un gráfico
fig = plt.figure()
plt.plot(x, np.sin(x))

# %%
#Dos gráficos
fig = plt.figure()
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %%
#Varios gráficos especificando color
fig = plt.figure()
plt.plot(x, np.sin(x - 0), color='blue')        # color por nombre
plt.plot(x, np.sin(x - 1), color='g')           # codigo corto (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Escala de grises entre 0 y 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Codigo hexadecimal (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB , values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # HTML color

# %%
#Tipos de líneas
fig = plt.figure()

plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':'); # dotted

# %%
base_mes_edu.plot(kind='line', linestyle='--')
plt.title('Horas de ausentismo por mes y educacion ')
plt.xlabel('Meses')
plt.ylabel('Horas')
# Out:
# Text(0, 0.5, 'Horas')

# %%
fig = plt.figure()
plt.plot(base_mes_edu.index, base_mes_edu['graduate'], linestyle='-') 
plt.plot(base_mes_edu.index, base_mes_edu['high school'], linestyle='--') 
plt.title('Horas de ausentismo por mes y educacion ')
plt.legend(['graduate', 'high school'])
plt.xlabel('Meses')
plt.ylabel('Horas')
# Out:
# Text(0, 0.5, 'Horas')

# %%
#Zoom
fig = plt.figure()
plt.plot(base_mes_edu.index, base_mes_edu['graduate'], linestyle='-') 
plt.plot(base_mes_edu.index, base_mes_edu['high school'], linestyle='--') 
plt.title('Horas de ausentismo por mes y educacion ')
plt.legend(['graduate', 'high school'])
plt.xlabel('Meses')
plt.ylabel('Horas')
plt.xlim(10, 12)
plt.ylim(3, 10);

# %%
fig = plt.figure()
plt.plot(base_mes_edu.index, base_mes_edu['graduate'], linestyle='-') 
plt.plot(base_mes_edu.index, base_mes_edu['high school'], linestyle='--') 
plt.title('Horas de ausentismo por mes y educacion ')
plt.legend(['graduate', 'high school'])
plt.xlabel('Meses')
plt.ylabel('Horas')
plt.axis('tight') # vuelve a ajustar los límites
# Out:
# (-0.55, 11.55, 1.5625, 16.6875)

# %%
#Otra forma de poner las etiquetas

fig = plt.figure()
plt.plot(base_mes_edu.index, base_mes_edu['graduate'], '-g', label='graduate') 
plt.plot(base_mes_edu.index, base_mes_edu['high school'], ':b' , label='high school' ) 
plt.title('Horas de ausentismo por mes y educacion ')
plt.legend(['graduate', 'high school'])
plt.xlabel('Meses')
plt.ylabel('Horas')
plt.axis('tight') # vuelve a ajustar los límites
# Out:
# (-0.55, 11.55, 1.5625, 16.6875)

# %% [markdown]
# ####  *Elabore un gráfico de líneas entre la variable meses y la variable Work load Average/day, con líneas punteadas en color rojo*

# %%
base.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
base_mes_2 = base[['Month of absence', 'Work load Average/day ']]
base_mes_2 = base_mes_2.groupby(['Month of absence']).mean()
base_mes_2
# Out:
#                   Work load Average/day
# Month of absence
# 1                             314.797660
# 2                             270.207292
# 3                             268.159851
# 4                             274.851264
# 5                             275.067500
# 6                             298.012481
# 7                             249.814418
# 8                             238.005222
# 9                             264.974849
# 10                            269.072831
# 11                            284.743317
# 12                            257.628082

# %%
base_mes_2.plot(linestyle=':', color='r')
# Out:
# <Axes: xlabel='Month of absence'>

# %% [markdown]
# ### Scatterplot o Gráficos de Dispersión

# %%
plt.style.use('ggplot') #Cambiamos de estilo

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)
fig = plt.figure()
plt.plot(x, y, 'o', color='red');

# %%
fig = plt.figure()
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
fig = plt.figure()
plt.plot(x, y, 'g-o');   # linea (-), marcador circular (o), negro (k)

# %% [markdown]
# Por ejemplo analicemos la relación entre Gasto de Transporte y Distancia desde la Residencia al Trabajo

# %%
base_gt_drt = base[['Transportation expense', 'Distance from Residence to Work']]

# %%
base_gt_drt.plot(kind='scatter', x= 'Transportation expense', y= 'Distance from Residence to Work')
# Out:
# <Axes: xlabel='Transportation expense', ylabel='Distance from Residence to Work'>

# %%
x = base_gt_drt_r['Transportation expense']
y = base_gt_drt_r['Distance from Residence to Work']
fig = plt.figure()
plt.plot(x, y, '.', color='g');

# %%
fig = plt.figure()
plt.plot(x, y, 'o', #color='red',
        markersize=15, 
                        markerfacecolor='white',
                        markeredgecolor='green',
                        markeredgewidth=4)

# %%
plt.style.use('bmh')

# %%
# %matplotlib inline
x = base_gt_drt['Transportation expense']
y = base_gt_drt['Distance from Residence to Work']
fit = np.polyfit(x, y, deg=1)

fig = plt.figure()
plt.plot(x, y, '.', color='blue')
plt.xlabel('Gastos de transporte')
plt.ylabel('Distance de la Residencia al trabajo')
plt.plot(x, fit[0] * x + fit[1], color='red') # dibujar la recta ajustada
plt.annotate('y = {0:.2f} x + {1:.2f}'.format(fit[0], fit[1]), xy=(300, 40))
plt.show()
'Distancia Trabajo = {0:.3f} * Gasto Transporte + {1:.3f}'.format(fit[0], fit[1])
# Out:
# 'Distancia Trabajo = 0.058 * Gasto Transporte + 16.773'

# %%
plt.style.use('ggplot')

# %% [markdown]
# Usando el método SCATTER se tienen más opciones

# %%
base_gt_drt_ed = base[['Transportation expense', 'Distance from Residence to Work', 'Age']]
base_gt_drt_ed_r = base_gt_drt_ed.sample(100) #Solo para tener 100 puntos
x = base_gt_drt_ed_r['Transportation expense']
y = base_gt_drt_ed_r['Distance from Residence to Work']
colors = base_gt_drt_ed_r['Age']
fig = plt.figure()
plt.scatter(x, y, c=colors, alpha=0.3)
plt.colorbar()  # mostrar la escala de colores
plt.xlabel('Gastos de transporte')
plt.ylabel('Distance de la Residencia al trabajo')
# Out:
# Text(0, 0.5, 'Distance de la Residencia al trabajo')

# %% [markdown]
# Inclusive con el tamaño de las burbujas

# %%
base['Month of absence'].replace({1:'ene', 2:'feb', 3:'mar', 4:'abr', 5:'may', 6:'jun', 7:'jul', 8:'ago', 9:'sep', 10:'oct', 11:'nov', 12:'dic'}, inplace=True)
base_d_edu_au = base[['Month of absence', 'Education', 'Absenteeism time in hours']]
base_d_edu_au_r = base_d_edu_au.sample(100) #Solo para tener 100 puntos
x = base_d_edu_au_r['Month of absence']
y = base_d_edu_au_r['Education']
size = base_d_edu_au_r['Absenteeism time in hours']
fig = plt.figure(figsize=(6, 6))
plt.scatter(x, y, sizes = size*10, alpha=0.5)
#plt.colorbar()  # show color scale
plt.xlabel('Mes')
plt.ylabel('Educación')
plt.legend(['Horas de ausentismo'], loc='upper left', fontsize='x-large')
# Out:
# C:\Users\rclaure\AppData\Local\Temp\ipykernel_53856\309367944.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base['Month of absence'].replace({1:'ene', 2:'feb', 3:'mar', 4:'abr', 5:'may', 6:'jun', 7:'jul', 8:'ago', 9:'sep', 10:'oct', 11:'nov', 12:'dic'}, inplace=True)

# %% [markdown]
# base_gt_drt_ed

# %%
base.head()
# Out:
#    ID  Reason for absence Month of absence  Day of the week  Seasons  \
# 0  11                  26              jul                3        1
# 1  36                   0              jul                3        1
# 2   3                  23              jul                4        1
# 3   7                   7              jul                5        1
# 4  11                  23              jul                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Disciplinary failure    Education Son  \
# ...

# %% [markdown]
# #### *Realice un diagrama de dispersión con  las variables: Work load Average/day y Absenteeism time in hours, agregue una línea de tendencia, agregue la ecuación dentro del gráfico*\
# #### *Realice un diagrama de burbujas, entre las variables: Distance from Residence to Work y Service time, con la variable: "Son"(hijos)	que defina el color de la burbuja*

# %% [markdown]
# ### Gráficos de áreas

# %%
base_mes_edu.plot(kind='area', 
             alpha=0.25, # 0-1
             stacked=True,
             figsize=(10, 7),
            )

plt.title('Ausentismo Por Mes y Grado de educación')
plt.ylabel('Ausentismo')
plt.xlabel('Mes')

plt.show()

# %%
#Usemos el Artist Layer

ax = base_mes_edu.plot(kind='area', alpha=0.35, figsize=(10, 5))
ax.set_title('Ausentismo Por Mes y Grado de educación')
ax.set_ylabel('Ausentismo')
ax.set_xlabel('Mes')
# Out:
# Text(0.5, 0, 'Mes')

# %% [markdown]
# #### *Cree un diagrama de área con las variables: Mes, Educación y el promedio de edad, utilizando el ARTIST LAYER*

# %% [markdown]
# ### Diagramas de frecuencia, Histogramas

# %%
plt.style.use('classic')
fig = plt.figure()
data = np.random.randn(1000)
plt.hist(data);

# %%
fig = plt.figure()
plt.hist(data, bins=50, alpha=0.5,
         histtype='stepfilled', color='steelblue',edgecolor='black');

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3,  bins=40)

fig = plt.figure()
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %%
base.head()

# %%
base_au = base.loc[:,['Son','Absenteeism time in hours']] 
base_au['Son'] = np.where(base_au['Son']>0,1,base_au['Son'])
#base_au['Absenteeism time in hours'][base_au['Son']==0]

# %%
base_au
# Out:
#      Son  Absenteeism time in hours
# 0      1                          4
# 1      1                          0
# 2      0                          2
# 3      1                          4
# 4      1                          2
# ..   ...                        ...
# 732    1                          8
# 733    1                          8
# 734    1                         80
# 735    1                          8
# 736    1                          4
#
# [737 rows x 2 columns]

# %%
base_au['Son'].value_counts()
#df.where(df['Test3']<90, "A+")
# Out:
# Son
# 1    439
# 0    298
# Name: count, dtype: int64

# %%
fig = plt.figure()
plt.hist(base_au['Absenteeism time in hours'][base_au['Son']==1], alpha=0.5)
plt.hist(base_au['Absenteeism time in hours'][base_au['Son']==0], alpha=0.5)
plt.legend(['Con hijos', 'Sin hijos'] )

# %%
#Histograma con heatmap

# %%
media = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(media, cov, 10000).T

# %%
y
# Out:
# array([ 0.72616702,  0.57011879,  1.03154606, ..., -1.1657547 ,
#        -1.23419592,  0.90694583])

# %%
fig = plt.figure()
plt.hist2d(x, y, bins=30, cmap='Reds')
cb = plt.colorbar()
cb.set_label('cantidad por particion')
plt.savefig("grafico_ejemplo.jpg", format='jpg', dpi=300)

# %%
x = base['Service time']
y = base['Age']

# %%
fig = plt.figure()
plt.hist2d(x, y, bins=30, cmap='Reds')
cb = plt.colorbar()
cb.set_label('cantidad en particion')

# %% [markdown]
# ### Diagramas de Barras

# %%
base_mes_p = base_mes.groupby(['Month of absence']).mean()
base_mes_p.plot(kind='bar', figsize=(10, 6), rot=90) # rotar títulos ese X a 90 grados

plt.xlabel('Mes')
plt.ylabel('Promedio horas de ausentismo')
plt.title('Promedio horas de ausentismo por mes');

# %%
base_mes.plot(kind='bar', figsize=(10, 6), rot=90, color='r') # rotar título de eje X a 90 grados

plt.xlabel('Mes')
plt.ylabel('Promedio horas de ausentismo')
plt.title('Promedio horas de ausentismo por mes')

#para agregar una flecha
plt.annotate('',                      # sejara un espacio vacio
             xy=(2, 700),             # cabeza
             xytext=(1, 300),         # base
             xycoords='data',         # escala de los datos, usa la base
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='blue', lw=2)
            )
plt.annotate('Alergias', # texto
             xy=(1, 400),                    # Inicio
             rotation=73.4,                  # Ojimetro
             va='bottom',                    # alineamiento
             ha='left',                      # dirección
            )

plt.show();

# %% [markdown]
# ### Diagramas de caja

# %%
base.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
base_hijos = base[['ID', 'Son', 'Transportation expense' ]]

# %%
fig = plt.figure()
base_te =  base_hijos['Transportation expense']
base_te.plot(kind='box', figsize=(6, 6))
plt.show()

# %%
#Forma incorrecta para más de una variable
base_hijos = base_hijos.loc[:,['ID', 'Son','Transportation expense']] 
base_hijos['Son'] = np.where(base_au['Son']>0,1,base_au['Son'])

fig = plt.figure()
plt.boxplot(base_hijos['Transportation expense'][base_au['Son']==1])
plt.boxplot(base_hijos['Transportation expense'][base_au['Son']==0])
plt.figsize=(20, 10)
plt.legend(['Con hijos', 'Sin hijos'] )

# %%
base_hijos2 = base_hijos.pivot_table(index='ID', columns=['Son'], values=['Transportation expense'] )#.droplevel(0)
base_hijos2.columns = ['sin hijos', 'con hijos']
base_hijos2
# Out:
#     sin hijos  con hijos
# ID
# 1         NaN      235.0
# 2         NaN      235.0
# 3       179.0        NaN
# 5         NaN      235.0
# 6         NaN      189.0
# 7         NaN      279.0
# 8         NaN      231.0
# 9         NaN      228.0
# 10        NaN      361.0
# 11        NaN      289.0
# 12        NaN      233.0
# 13        NaN      369.0
# 14        NaN      155.0
# 15        NaN      291.0
# 16        NaN      118.0
# 17        NaN      179.0
# 18      330.0        NaN
# 19      291.0        NaN
# 20        NaN      260.0
# 21      268.0        NaN
# 22      179.0        NaN
# 23        NaN      378.0
# 24      246.0        NaN
# 25      235.0        NaN
# 26        NaN      300.0
# 27      184.0        NaN
# 28        NaN      225.0
# 29        NaN      225.0
# 30      157.0        NaN
# 31      388.0        NaN
# 32      289.0        NaN
# 33        NaN      248.0
# 34      118.0        NaN
# 36        NaN      118.0

# %%
base_hijos2.head(3)
# Out:
#     sin hijos  con hijos
# ID
# 1         NaN      235.0
# 2         NaN      235.0
# 3       179.0        NaN

# %%
base_hijos2.plot(kind='box', figsize=(6, 6))
# Out:
# <Axes: >

# %%
base_hijos2.plot(kind='box', figsize=(10, 5), color='green', vert=False)
# Out:
# <Axes: >

# %% [markdown]
# #### Multigráficos

# %%
fig = plt.figure() 

ax0 = fig.add_subplot(2, 2, 1) # Primer grafico
ax1 = fig.add_subplot(2, 2, 2) # Segundo grafico
ax2 = fig.add_subplot(2, 2, 3) # Segundo grafico
ax3 = fig.add_subplot(2, 2, 4) # Segundo grafico

base_hijos2.plot(kind='box', figsize=(10, 5), color='green', vert=False, ax=ax0)
ax0.set_title('Costos de transporte Con/Sin Hijos')
ax0.set_xlabel('Costos')
ax0.set_ylabel('Hijos')

base_mes.plot(figsize=(10, 5), ax=ax1, color='blue')
ax1.set_title ('Ausentismo Anual en Horas')
ax1.set_ylabel('Total Horas')
ax1.set_xlabel('Meses')
plt.figsize=(20, 10)

base_hijos2.plot(kind='box', figsize=(10, 5), color='red', vert=True, ax=ax2)
ax0.set_title('Costos de transporte Con/Sin Hijos')
ax0.set_xlabel('Costos')
ax0.set_ylabel('Hijos')

base_mes.plot(figsize=(10, 5), ax=ax3, color='k')
ax1.set_title ('Ausentismo Anual en Horas')
ax1.set_ylabel('Total Horas')
ax1.set_xlabel('Meses')
plt.figsize=(20, 10)

plt.show()

# %% [markdown]
# ### Graficos de Torta o PieChart

# %%
base_mes = base[['Month of absence', 'Absenteeism time in hours']]
base_mes2 = base_mes.groupby(['Month of absence']).sum()

# %%
fig = plt.figure() 
base_mes2['Absenteeism time in hours'].plot(kind='pie')
# Out:
# <Axes: ylabel='Absenteeism time in hours'>

# %%
#Gráfico más completo

fig = plt.figure() 
base_mes2['Absenteeism time in hours'].plot(kind='pie',
                            figsize=(10, 6),
                            autopct='%1.1f%%', 
                            startangle=180,    
                            shadow=True,       
                            labels=None,                 # quitar la etiquetas dentro del pie chart
                            pctdistance=1.12,            #la relacion entre el grafico y los bordes
                            explode=[0, 0, 0, 0.5, 0, 0, 0, 0, 0.5, 0, 0, 0 ]         # desfazar un pedazo
                            )


plt.title('Ausentismo', y=1.12) 
plt.axis('equal') 


plt.legend(labels=base_mes2.index, loc='upper left') 

plt.axis('tight')
plt.show()
